# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
prices_data = pd.read_csv('../data/raw/prices.csv')

# %%
prices_data.head()
# Out:
#          date      admin1      admin2            market         market_id  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name  #loc+market+code
# 1  2004-01-15     Western     Colombo      Colombo City               368
# 2  2004-02-15     Western     Colombo      Colombo City               368
# 3  2004-02-15     Western     Colombo      Colombo City               368
# 4  2004-03-15     Western     Colombo      Colombo City               368
#
#    latitude longitude            category        commodity commodity_id  \
# 0  #geo+lat  #geo+lon          #item+type       #item+name   #item+code
# 1      6.93     79.85  cereals and tubers      Wheat flour           58
# 2      6.93     79.85  cereals and tubers  Rice (red nadu)          157
# 3      6.93     79.85  cereals and tubers      Wheat flour           58
# 4      6.93     79.85  cereals and tubers      Wheat flour           58
#
#          unit         priceflag         pricetype        currency   price  \
# ...

# %%
riceprice_data = pd.read_csv('../data/processed/rice_prices.csv')

# %%
riceprice_data.head()
# Out:
#          date   admin1   admin2        market  market_id  latitude  longitude  \
# 0  2004-02-15  Western  Colombo  Colombo City        368      6.93      79.85
# 1  2004-04-15  Western  Colombo  Colombo City        368      6.93      79.85
# 2  2004-05-15  Western  Colombo  Colombo City        368      6.93      79.85
# 3  2004-06-15  Western  Colombo  Colombo City        368      6.93      79.85
# 4  2004-07-15  Western  Colombo  Colombo City        368      6.93      79.85
#
#              category        commodity  commodity_id unit priceflag pricetype  \
# 0  cereals and tubers  Rice (red nadu)           157   KG    actual    Retail
# 1  cereals and tubers  Rice (red nadu)           157   KG    actual    Retail
# 2  cereals and tubers  Rice (red nadu)           157   KG    actual    Retail
# 3  cereals and tubers  Rice (red nadu)           157   KG    actual    Retail
# 4  cereals and tubers  Rice (red nadu)           157   KG    actual    Retail
#
# ...

# %%
unique_markets = riceprice_data['market'].unique()
unique_markets
# Out:
# array(['Colombo City', 'Ampara', 'Trincomalee', 'Jaffna', 'Kilinochchi',
#        'Mannar', 'Mulaitivu', 'Vavuniya', 'Batticaloa',
#        'National Average', 'Monaragala', 'Badulla', 'Matara',
#        'Hambantota', 'Galle', 'Rathnapura', 'Puttalam', 'Nuwara Eliya',
#        'Kandy', 'Gampaha', 'Polonnaruwa', 'Matale', 'Kalutara',
#        'Anuradhapura', 'Kurunegala', 'Kegalle',
#        'Economic Centre-Maradagahamula', 'Economic Centre-Pettah',
#        'Mullativu', 'Embilipitiya', 'Keppetipola (DEC}', 'Dammbagalla',
#        'Meegoda(DEC)', 'Hanguranketha', 'Dehiattakandiya',
#        'Thambuttegama', 'Galenbindunuwewa', 'Nikaweratiya',
#        'Tissamaharama', 'Bandarawela'], dtype=object)

# %%
unique_categories = riceprice_data['category'].unique()
unique_categories
# Out:
# array(['cereals and tubers'], dtype=object)

# %%
unique_commodities = riceprice_data['commodity'].unique()
unique_commodities
# Out:
# array(['Rice (red nadu)', 'Rice (white)', 'Rice (long grain)',
#        'Rice (red)', 'Rice (medium grain)'], dtype=object)

# %%
unique_priceflags = riceprice_data['priceflag'].unique()
unique_priceflags
# Out:
# array(['actual'], dtype=object)

# %%
rainfall_data = pd.read_csv('../data/raw/rainfall.csv')
rainfall_data.head(10)
# Out:
#          date         adm_level   adm_id      PCODE                 n_pixels  \
# 0       #date  #adm+level+level  #adm+id  #adm+code  #indicator+n_pixels+num
# 1  1981-01-01                 2    25830       LK22                     67.0
# 2  1981-01-11                 2    25830       LK22                     67.0
# 3  1981-01-21                 2    25830       LK22                     67.0
# 4  1981-02-01                 2    25830       LK22                     67.0
# 5  1981-02-11                 2    25830       LK22                     67.0
# 6  1981-02-21                 2    25830       LK22                     67.0
# 7  1981-03-01                 2    25830       LK22                     67.0
# 8  1981-03-11                 2    25830       LK22                     67.0
# 9  1981-03-21                 2    25830       LK22                     67.0
#
#                   rfh                 rfh_avg                 r1h  \
# ...

# %%
rainfall_data.tail(10)
# Out:
#              date adm_level adm_id PCODE n_pixels        rfh    rfh_avg  \
# 54629  2025-05-11         2  25853  LK13     52.0      97.25  157.04744
# 54630  2025-05-21         2  25853  LK13     52.0  127.23077  152.78078
# 54631  2025-06-01         2  25853  LK13     52.0   41.03846  120.14744
# 54632  2025-06-11         2  25853  LK13     52.0  114.03846  98.059616
# 54633  2025-06-21         2  25853  LK13     52.0  60.634617   91.52372
# 54634  2025-07-01         2  25853  LK13     52.0  30.634615   66.38269
# 54635  2025-07-11         2  25853  LK13     52.0   39.78846  73.113464
# 54636  2025-07-21         2  25853  LK13     52.0   44.53846   68.05321
# 54637  2025-08-01         2  25853  LK13     52.0  55.884617  46.305126
# 54638  2025-08-11         2  25853  LK13     52.0       37.5   65.85577
#
#              r1h    r1h_avg        r3h    r3h_avg        rfq        r1q  \
# 54629  367.69232  422.95258  1162.1731   829.2128  63.098804  87.087296
# ...

# %%
rainfall_data['PCODE'].unique()
# Out:
# array(['#adm+code', 'LK22', 'LK52', 'LK51', 'LK53', 'LK71', 'LK21', 'LK2',
#        'LK72', 'LK61', 'LK23', 'LK5', 'LK7', 'LK62', 'LK6', 'LK41', 'LK4',
#        'LK9', 'LK45', 'LK42', 'LK3', 'LK44', 'LK8', 'LK43', 'LK1', 'LK92',
#        'LK91', 'LK31', 'LK33', 'LK32', 'LK81', 'LK82', 'LK11', 'LK12',
#        'LK13'], dtype=object)

# %%
agg_rainfall = pd.read_csv('../data/processed/agg_rainfall.csv')
agg_rainfall.head()
# Out:
#    year season        rfh    rfh_avg         r1h     r1h_avg         r3h  \
# 0  1981   Maha  50.558112  64.505060  150.630109  189.143212  478.042561
# 1  1981   Yala  42.344631  43.156226  126.965443  129.960975  352.342262
# 2  1982   Maha  54.377813  64.505060  158.149800  193.145948  429.120483
# 3  1982   Yala  33.225513  43.156226  101.673453  129.960975  287.941523
# 4  1983   Maha  43.524888  64.505060  117.334375  193.145948  425.224760
#
#       r3h_avg        rfq
# 0  528.603630  80.780471
# 1  394.665758  98.446236
# 2  575.058947  71.550214
# 3  394.665758  76.915509
# 4  575.058947  65.137874
